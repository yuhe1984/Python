# %%
from flask import Flask, request, render_template

app = Flask(__name__)

@app.route('/', methods=['GET', 'POST'])
def home():
    return render_template('home.html')

@app.route('/signin', methods=['GET'])
def signin_form():
    return render_template('from.html')

@app.route('/signin', methods=['POST'])
def signin():
    # 需要从request对象读取表单内容：
    username = request.form['username']
    passward = request.form['password']
    if username=='admin' and password=='password':
        return render_template('signin-ok.html', username=username)
    return render_template('form.html', message='Bad username or password', username=username)

if __name__ == '__main__':
    app.run()
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/Oct/2019 09:04:36] "GET / HTTP/1.1" 200 -
# [2019-10-22 09:04:42,723] ERROR in app: Exception on /signin [GET]
# Traceback (most recent call last):
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1982, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1614, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1517, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\Anaconda\lib\site-packages\flask\_compat.py", line 33, in reraise
#     raise value
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1612, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1598, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-2-63db71214c70>", line 11, in signin_form
#     return render_template('from.html')
#   File "D:\Anaconda\lib\site-packages\flask\templating.py", line 133, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "D:\Anaconda\lib\site-packages\jinja2\environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "D:\Anaconda\lib\site-packages\jinja2\environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "D:\Anaconda\lib\site-packages\jinja2\environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "D:\Anaconda\lib\site-packages\jinja2\loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "D:\Anaconda\lib\site-packages\flask\templating.py", line 57, in get_source
#     return self._get_source_fast(environment, template)
#   File "D:\Anaconda\lib\site-packages\flask\templating.py", line 85, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: from.html
# 127.0.0.1 - - [22/Oct/2019 09:04:42] "GET /signin HTTP/1.1" 500 -
# 127.0.0.1 - - [22/Oct/2019 09:49:51] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [22/Oct/2019 09:49:52] "GET / HTTP/1.1" 200 -
# [2019-10-22 09:50:02,003] ERROR in app: Exception on /signin [GET]
# Traceback (most recent call last):
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1982, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1614, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1517, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\Anaconda\lib\site-packages\flask\_compat.py", line 33, in reraise
#     raise value
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1612, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1598, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-2-63db71214c70>", line 11, in signin_form
#     return render_template('from.html')
#   File "D:\Anaconda\lib\site-packages\flask\templating.py", line 133, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "D:\Anaconda\lib\site-packages\jinja2\environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "D:\Anaconda\lib\site-packages\jinja2\environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "D:\Anaconda\lib\site-packages\jinja2\environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "D:\Anaconda\lib\site-packages\jinja2\loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "D:\Anaconda\lib\site-packages\flask\templating.py", line 57, in get_source
#     return self._get_source_fast(environment, template)
#   File "D:\Anaconda\lib\site-packages\flask\templating.py", line 85, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: from.html
# 127.0.0.1 - - [22/Oct/2019 09:50:02] "GET /signin HTTP/1.1" 500 -
